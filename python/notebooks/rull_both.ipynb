# %%
from google.colab import drive
from pathlib import Path
import sys
import os

drive.mount('/content/drive', force_remount=True)

PROJECT_ROOT = Path('/content/drive/Othercomputers/My Laptop/thesis_project')

if str(PROJECT_ROOT) not in sys.path:
    sys.path.append(str(PROJECT_ROOT))

os.chdir(PROJECT_ROOT)

print("Working directory:", os.getcwd())
# Out:
# Mounted at /content/drive
# Working directory: /content/drive/Othercomputers/My Laptop/thesis_project

# %%
from python.src.train.model_trainer import train_model
from pathlib import Path
import torch
import os

PROJECT_ROOT = Path.cwd()

models = ["asymmetric_trinet"]
version = "v2"
seeds = [146]
n_per_class = [2500]
epochs = 20


for m in models:
  for s in seeds:
    for n in n_per_class:

      print(f"\n\nRunning experiment model = {m}, seed = {s}, n_per_class = {n}")
      print("============================================================================\n")

      trained_model = train_model(seed=s,
                  project_root=PROJECT_ROOT,
                  model_name=m,
                  n_per_class=n,
                  spec_version=version,
                  n_epochs=epochs
                  )
      # clean up RAM
      del trained_model
      if torch.cuda.is_available():
            torch.cuda.empty_cache()
      elif hasattr(torch.backends, "mps") and torch.backends.mps.is_available():
            torch.mps.empty_cache()
      print("\nTraining finished")
# Out:
# Running experiment model = asymmetric_trinet, seed = 146, n_per_class = 2500
# ============================================================================
#
#
# Validation report found: /content/drive/Othercomputers/My Laptop/thesis_project/reports/validations/validation_seed146_n2500_v2.json
# Starting training...
#
# Using device: cuda
#
# Epoch 01 | LR: 0.001000 | Train: 2.0103 (CE 1.6976 / SupCon 3.1270) | Val Loss: 1.3192 | Val Acc: 63.42
# Epoch 05 | LR: 0.000905 | Train: 1.0869 (CE 0.8759 / SupCon 2.1103) | Val Loss: 0.6909 | Val Acc: 91.88
# Epoch 10 | LR: 0.000578 | Train: 0.9463 (CE 0.7551 / SupCon 1.9124) | Val Loss: 0.6811 | Val Acc: 92.07
# Epoch 15 | LR: 0.000206 | Train: 0.8485 (CE 0.6749 / SupCon 1.7365) | Val Loss: 0.6569 | Val Acc: 93.23
# Epoch 20 | LR: 0.000006 | Train: 0.7822 (CE 0.6214 / SupCon 1.6078) | Val Loss: 0.6530 | Val Acc: 94.00
#
# Model saved to: /content/drive/Othercomputers/My Laptop/thesis_project/artifacts/checkpoints/asymmetric_trinet_seed146_n2500.pt
# Training log saved to: /content/drive/Othercomputers/My Laptop/thesis_project/artifacts/logs/training/asymmetric_trinet_training_seed146_n2500(3).json
# Figures saved to: /content/drive/Othercomputers/My Laptop/thesis_project/reports/figures/asymmetric_trinet_seed146_n2500(3)
#
# Best validation accuracy: 94.05
# Final TEST accuracy: 99.54 | Loss: 0.5165
#
# Training finished

# %%
from python.src.train.osr_trainer import train_osr_model
from python.src.train.osr_hparams import OSRHParams
from pathlib import Path
import torch

PROJECT_ROOT = Path.cwd()

version = "v2"
seeds = [146]
n_per_class = [2500]
epochs = 30

# Initialize hyperparameters (tweak these directly here if needed)
hparams = OSRHParams()

for s in seeds:
    for n in n_per_class:

        print(f"\n\nRunning OSR experiment | seed = {s}, n_per_class = {n}")
        print("============================================================================\n")

        trained_model = train_osr_model(
            seed=s,
            n_per_class=n,
            spec_version=version,
            project_root=PROJECT_ROOT,
            epochs=epochs,
            hparams=hparams
        )

        # clean up RAM
        del trained_model
        if torch.cuda.is_available():
            torch.cuda.empty_cache()
        elif hasattr(torch.backends, "mps") and torch.backends.mps.is_available():
            torch.mps.empty_cache()

        print("Trainng Complete")
# Out:
# Running OSR experiment | seed = 146, n_per_class = 2500
# ============================================================================
#
#
# ============================================================
# OsrSAF_TriNet | seed=146 | n=2500
# Device              : cuda
# Closed-set ckpt     : asymmetric_trinet_seed146_n2500.pt
# Codebook fill epochs: 15
# Phase 2 (calibrator): until epoch 30
# FPR cap (Youden)    : 0.40
# Recal interval      : 1
# ============================================================
#
# [load_osr_datasets] proxy unknowns: 5000 samples (train 4000 / val 1000)
# [load_osr_datasets] test  unknowns: 2000 samples (held out)
# [OsrSAF_TriNet] Loaded backbone from /content/drive/Othercomputers/My Laptop/thesis_project/artifacts/checkpoints/asymmetric_trinet_seed146_n2500.pt
#
# [Stage 2.A] Populating codebook over 15 epochs (frozen backbone)
#
#   Fill epoch 1/15 | init=100% | spread=0.2117 | updates/centroid=375.0
#   Fill epoch 2/15 | init=100% | spread=0.2499 | updates/centroid=748.7
#   Fill epoch 3/15 | init=100% | spread=0.2347 | updates/centroid=1120.2
#   Fill epoch 4/15 | init=100% | spread=0.2499 | updates/centroid=1493.1
#   Fill epoch 5/15 | init=100% | spread=0.2409 | updates/centroid=1864.0
#   Fill epoch 6/15 | init=100% | spread=0.2227 | updates/centroid=2236.8
#   Fill epoch 7/15 | init=100% | spread=0.2440 | updates/centroid=2608.7
#   Fill epoch 8/15 | init=100% | spread=0.2596 | updates/centroid=2980.3
#   Fill epoch 9/15 | init=100% | spread=0.2612 | updates/centroid=3351.9
#   Fill epoch 10/15 | init=100% | spread=0.2408 | updates/centroid=3725.6
#   Fill epoch 11/15 | init=100% | spread=0.2355 | updates/centroid=4097.0
#   Fill epoch 12/15 | init=100% | spread=0.2474 | updates/centroid=4469.0
#   Fill epoch 13/15 | init=100% | spread=0.2357 | updates/centroid=4839.3
#   Fill epoch 14/15 | init=100% | spread=0.2517 | updates/centroid=5210.8
#   Fill epoch 15/15 | init=100% | spread=0.2373 | updates/centroid=5583.2
#
# [Stage 2.B] Training calibrator on proxy unknowns
#
# Ep     | Loss    | KnAcc  | AUROC  | Recall | FPR    | J       | Thr    | Codebook
# --------------------------------------------------------------------------------------------
# 01/30 | 0.3913  | 0.939  | 0.7575 | 0.669  | 0.178  | +0.4908 | 0.430  | 100%
# 02/30 | 0.3297  | 0.939  | 0.7435 | 0.642  | 0.140  | +0.5025 | 0.600  | 100%
# 03/30 | 0.3116  | 0.939  | 0.7478 | 0.608  | 0.091  | +0.5165 | 0.480  | 100%
# 04/30 | 0.2893  | 0.939  | 0.7620 | 0.609  | 0.066  | +0.5433 | 0.660  | 100%
# 05/30 | 0.2715  | 0.939  | 0.7749 | 0.612  | 0.067  | +0.5453 | 0.770  | 100%
# 06/30 | 0.2608  | 0.939  | 0.7897 | 0.629  | 0.085  | +0.5445 | 0.590  | 100%
# 07/30 | 0.2455  | 0.939  | 0.8248 | 0.646  | 0.082  | +0.5637 | 0.680  | 100%
# 08/30 | 0.2388  | 0.939  | 0.8601 | 0.732  | 0.144  | +0.5882 | 0.650  | 100%
# 09/30 | 0.2287  | 0.939  | 0.8703 | 0.725  | 0.143  | +0.5817 | 0.390  | 100%
# 10/30 | 0.2185  | 0.939  | 0.8648 | 0.714  | 0.142  | +0.5715 | 0.520  | 100%
# 11/30 | 0.2150  | 0.939  | 0.8626 | 0.695  | 0.129  | +0.5660 | 0.680  | 100%
# 12/30 | 0.2086  | 0.939  | 0.9012 | 0.782  | 0.174  | +0.6075 | 0.410  | 100%
# 13/30 | 0.2055  | 0.939  | 0.9011 | 0.856  | 0.253  | +0.6035 | 0.310  | 100%
# 14/30 | 0.1990  | 0.939  | 0.8966 | 0.766  | 0.180  | +0.5857 | 0.390  | 100%
# 15/30 | 0.1975  | 0.939  | 0.9028 | 0.853  | 0.251  | +0.6022 | 0.260  | 100%
# 16/30 | 0.1943  | 0.939  | 0.8978 | 0.824  | 0.234  | +0.5895 | 0.280  | 100%
# 17/30 | 0.1918  | 0.939  | 0.9027 | 0.852  | 0.253  | +0.5995 | 0.240  | 100%
# 18/30 | 0.1964  | 0.939  | 0.8969 | 0.871  | 0.282  | +0.5890 | 0.240  | 100%
# 19/30 | 0.1891  | 0.939  | 0.9046 | 0.864  | 0.247  | +0.6170 | 0.260  | 100%
# 20/30 | 0.1894  | 0.939  | 0.9139 | 0.863  | 0.216  | +0.6472 | 0.270  | 100%
# 21/30 | 0.1918  | 0.939  | 0.8984 | 0.858  | 0.261  | +0.5970 | 0.320  | 100%
# 22/30 | 0.1849  | 0.939  | 0.9051 | 0.870  | 0.252  | +0.6178 | 0.250  | 100%
# 23/30 | 0.1860  | 0.939  | 0.9031 | 0.860  | 0.243  | +0.6170 | 0.330  | 100%
# 24/30 | 0.1835  | 0.939  | 0.9125 | 0.899  | 0.256  | +0.6428 | 0.250  | 100%
# 25/30 | 0.1850  | 0.939  | 0.9111 | 0.870  | 0.236  | +0.6342 | 0.240  | 100%
# 26/30 | 0.1831  | 0.939  | 0.9109 | 0.888  | 0.252  | +0.6358 | 0.240  | 100%
# 27/30 | 0.1836  | 0.939  | 0.9100 | 0.896  | 0.265  | +0.6313 | 0.240  | 100%
# 28/30 | 0.1835  | 0.939  | 0.9112 | 0.871  | 0.234  | +0.6372 | 0.270  | 100%
# 29/30 | 0.1812  | 0.939  | 0.9104 | 0.884  | 0.250  | +0.6340 | 0.250  | 100%
# 30/30 | 0.1816  | 0.939  | 0.9101 | 0.869  | 0.236  | +0.6328 | 0.270  | 100%
#
# Loaded best calibrator checkpoint (val AUROC = 0.9139)
# [OsrSAF_TriNet] Youden global threshold: t = 0.2700 | val TPR = 0.863 | val FPR = 0.216
#
# ====================================================
# FINAL TEST RESULTS
# Known accuracy  : 0.9960
# AUROC           : 0.9251
# Unknown recall  : 0.8880
# False alarm rate: 0.1913
# Youden's J      : +0.6967
# Final threshold : 0.2700
# ====================================================
#
#
# Feature                 Known μ    Unk μ    Sep↑
# --------------------------------------------------
# code_dist                 0.012    0.174    1.59
# unc                       0.040    0.226    1.46
# emb_norm_norm             0.333    0.333    0.00
# runner_up_dist            0.868    0.631    1.33
# margin_codebook           0.856    0.465    1.60
# logit_margin_sq           0.718    0.412    1.83
# hamming_dist_pred         0.055    0.213    2.10
# hamming_margin            0.356    0.141    2.05
#
# Feature stats saved to: /content/drive/Othercomputers/My Laptop/thesis_project/artifacts/logs/osr_training/feature_stats_seed146_n2500.json
# Generating OSR diagnostics in: /content/drive/Othercomputers/My Laptop/thesis_project/reports/figures/osr_saf_trinet_seed146_n2500
# Trainng Complete
